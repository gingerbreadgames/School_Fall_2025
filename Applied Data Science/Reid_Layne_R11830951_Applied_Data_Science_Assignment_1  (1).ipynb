# %% [markdown]
# - - - -
# **<font color='red'>Task 1:</font>
# Analyzing US Economic Data**
#
# - - - -
#
#
# Description

# %% [markdown]
# Extracting essential data from a dataset and displaying it is a necessary part of data science; therefore individuals can make correct decisions based on the data. In this assignment, you will extract some essential economic indicators from some data.
# <p>
# <a href="https://en.wikipedia.org/wiki/Gross_domestic_product"> Gross domestic product (GDP)</a> is a measure of the market value of all the final goods and services produced in a period. GDP is an indicator of how well the economy is doing. A drop in GDP indicates the economy is producing less; similarly an increase in GDP suggests the economy is performing better. In this lab, you will examine how changes in GDP impact the unemployment rate. </p>

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#     <li><a href="#Section_2">Question 1: Create a dataframe that contains the GDP data and display it</a> </li>
#     <li><a href="#Section_3">Question 2: Basic Insight of Dataset</a></li>
#     <li><a href="#Section_4">Question 3: Create a dataframe that contains the unemployment data and display it</a></li>
#     <li><a href="#Section_5">Question 4: Display a dataframe where unemployment was greater than 8.5%</a></li>
#     <li><a href="#Section_6">Question 5: Print out some data</a></li>
# </div>
#
# <hr>

# %% [markdown]
# We will import the following libraries.

# %%
import pandas as pd
from bokeh.io import push_notebook, output_file,show, output_notebook

from bokeh.layouts import row

from bokeh.plotting import figure
output_notebook()

# %% [markdown]
# The dictionary  <code>links</code> contain the CSV files with all the data. The value for the key <code>GDP</code> is the file that contains the GDP data. The value for the key <code>unemployment</code> contains the unemployment data.

# %%
links={'GDP':'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_gdp.csv',\
       'unemployment':'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/projects/coursera_project/clean_unemployment.csv'}

# %% [markdown]
# <h3 id="Section_2"> Question 1: Create a dataframe that contains the GDP data and display the first five rows of the dataframe.</h3>

# %% [markdown]
# Use the dictionary <code>links</code> and the function <code>pd.read_csv</code> to create a Pandas dataframes that contains the GDP data.

# %% [markdown]
# <b>Hint: <code>links["GDP"]</code> contains the path or name of the file.</b>

# %% [markdown]
# Use the method <code>head()</code> to display the first five rows of the GDP data.

# %%
# TODO: Write code to create a Pandas dataframes that contains the GDP data.
# Your code here:
data = pd.read_csv(links["GDP"])
print(data.head())
# Out:
#    date  level-current  level-chained  change-current  change-chained
# 0  1948          274.8         2020.0            -0.7            -0.6
# 1  1949          272.8         2008.9            10.0             8.7
# 2  1950          300.2         2184.0            15.7             8.0
# 3  1951          347.3         2360.0             5.9             4.1
# 4  1952          367.7         2456.1             6.0             4.7

# %% [markdown]
# <h3 id="Section_2"> Question 2: Basic Insight of Dataset</h3>
# <p>
# After reading data into Pandas dataframe, it is time for us to explore the dataset.<br>
#
# There are several ways to obtain essential insights of the data to help us better understand our dataset.

# %% [markdown]
# Describe
#
# If we would like to get a statistical summary of each column e.g. count, column mean value, column standard deviation, etc., we use the describe method:

# %%
# Your code here:
print(data.describe())
# Out:
#               date  level-current  level-chained  change-current  \
# count    69.000000      69.000000      69.000000       69.000000
# mean   1982.000000    5664.008696    7957.673913        6.424638
# std      20.062403    5692.268651    4585.249853        3.200616
# min    1948.000000     272.800000    2008.900000       -1.800000
# 25%    1965.000000     743.700000    3976.700000        4.300000
# 50%    1982.000000    3345.000000    6617.700000        6.000000
# 75%    1999.000000    9660.600000   12065.900000        8.400000
# max    2016.000000   18624.500000   16716.200000       15.700000
#
#        change-chained
# count       69.000000
# mean         3.184058
# std          2.341168
# min         -2.500000
# 25%          1.900000
# 50%          3.200000
# 75%          4.600000
# max          8.700000

# %% [markdown]
# This method will provide various summary statistics, excluding <code>NaN</code> (Not a Number) values.

# %% [markdown]
# Info
#
# Another method you can use to check your dataset is info:

# %%
# Your code here:
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            69 non-null     int64
#  1   level-current   69 non-null     float64
#  2   level-chained   69 non-null     float64
#  3   change-current  69 non-null     float64
#  4   change-chained  69 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 2.8 KB
# None

# %% [markdown]
# It provides a concise summary of your DataFrame.
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %% [markdown]
# <h4>Evaluating for Missing Data</h4>
#
# The missing values are converted by default. We use the following functions to identify these missing values. There are two methods to detect missing data:
#
# <ol>
#     <li><b>.isnull()</b></li>
#     <li><b>.notnull()</b></li>
# </ol>
# The output is a boolean value indicating whether the value that is passed into the argument is in fact missing data.

# %%
# Your code here:

print(data.isnull())
print(data.notnull())
# Out:
#      date  level-current  level-chained  change-current  change-chained
# 0   False          False          False           False           False
# 1   False          False          False           False           False
# 2   False          False          False           False           False
# 3   False          False          False           False           False
# 4   False          False          False           False           False
# ..    ...            ...            ...             ...             ...
# 64  False          False          False           False           False
# 65  False          False          False           False           False
# 66  False          False          False           False           False
# 67  False          False          False           False           False
# 68  False          False          False           False           False
#
# [69 rows x 5 columns]
#     date  level-current  level-chained  change-current  change-chained
# 0   True           True           True            True            True
# 1   True           True           True            True            True
# 2   True           True           True            True            True
# 3   True           True           True            True            True
# 4   True           True           True            True            True
# ..   ...            ...            ...             ...             ...
# 64  True           True           True            True            True
# 65  True           True           True            True            True
# 66  True           True           True            True            True
# 67  True           True           True            True            True
# 68  True           True           True            True            True
#
# [69 rows x 5 columns]

# %% [markdown]
# <h3 id="Section_2"> Question 3: Create a dataframe that contains the unemployment data. Display the first five rows of the dataframe. </h3>

# %% [markdown]
# Use the dictionary <code>links</code> and the function <code>pd.read_csv</code> to create a Pandas dataframes that contains the unemployment data.

# %% [markdown]
# Use the method <code>head()</code> to display the first five rows of the GDP data.

# %%
# Your code here:
data = pd.read_csv(links["unemployment"])
print(data.head())
# Out:
#    date  unemployment
# 0  1948      3.750000
# 1  1949      6.050000
# 2  1950      5.208333
# 3  1951      3.283333
# 4  1952      3.025000

# %% [markdown]
# <h3 id="Section_3">Question 4: Display a dataframe where unemployment was greater than 8.5%.</h3>

# %%
# Your code here:
print(data[data["unemployment"] > 8.5])
# Out:
#     date  unemployment
# 34  1982      9.708333
# 35  1983      9.600000
# 61  2009      9.283333
# 62  2010      9.608333
# 63  2011      8.933333

# %% [markdown]
# <h3 id="Section_4">Question 5: Printing out some data</h3>

# %% [markdown]
# Create a new dataframe with the column <code>'date'</code> called <code>x</code> from the dataframe that contains the GDP data.

# %%
# Your code here:
x = data["date"]
print(x)
# Out:
# 0     1948
# 1     1949
# 2     1950
# 3     1951
# 4     1952
#       ...
# 64    2012
# 65    2013
# 66    2014
# 67    2015
# 68    2016
# Name: date, Length: 69, dtype: int64

# %% [markdown]
# Create a new dataframe with the column <code>'change-current' </code> called <code>gdp_change</code>  from the dataframe that contains the GDP data.

# %%
# Your code here:
gdp_data = pd.read_csv(links["GDP"])
gdp_change = gdp_data[gdp_data.columns[3]]
print(gdp_change)
# Out:
# 0     -0.7
# 1     10.0
# 2     15.7
# 3      5.9
# 4      6.0
#       ...
# 64     3.6
# 65     4.4
# 66     4.0
# 67     2.7
# 68     4.2
# Name: change-current, Length: 69, dtype: float64

# %% [markdown]
# Create a new dataframe with the column <code>'unemployment' </code> called <code>unemployment</code>  from the dataframe that contains the  unemployment data.

# %%
# Your code here:
unemployment_data = pd.read_csv(links["unemployment"])
unemployment = data[unemployment_data.columns[1]]
print(unemployment)
# Out:
# 0     3.750000
# 1     6.050000
# 2     5.208333
# 3     3.283333
# 4     3.025000
#         ...
# 64    8.075000
# 65    7.358333
# 66    6.158333
# 67    5.275000
# 68    4.875000
# Name: unemployment, Length: 69, dtype: float64

# %% [markdown]
# - - - -
# **<font color='red'>Task 2:</font>
# Extracting Data Using a Web Scraping**
#
# - - - -
#
#
# Description

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>Downloading the Webpage Using Requests Library</li>
#         <li>Parsing Webpage HTML Using BeautifulSoup</li>
#         <li>Extracting Data and Building DataFrame</li>
#     </ul>
# </div>
#
# <hr>

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from bs4) (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->bs4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->bs4) (4.15.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Using Webscraping to Extract Data

# %% [markdown]
# Use the `requests` library to download the webpage. Save the text of the response as a variable named `html_data`.

# %%
# Your code here:

url = "https://www.sos.state.tx.us/elections/historical/lubbock.shtml"
html_data = requests.get(url).text

# %% [markdown]
# Parse the html data using `beautiful_soup`.

# %%
soup = BeautifulSoup(html_data, "html5lib")

# %% [markdown]
# <b>Question 1</b> what is the content of the title attribute:

# %%
# Your code here:
print(soup.title)
# Out:
# <title>Lubbock County Voter Registration Figures</title>

# %% [markdown]
# <b>Question 2</b> Extract the link in this webpage using "find_all" method.

# %%
# Your code here:
for link in soup.find_all('a', href=True):
    print(link['href'])
# Out:
# /#mainContent
# /statdoc/request.shtml
# /office-hours-notice.shtml
# /about/newsreleases/index.shtml
# /siteindex.shtml
# /help.shtml
# /contact.shtml
# https://www.surveymonkey.com/r/website-satisfaction-survey
# /sos_espanol.shtml
# /index.shtml
# /index.shtml
# /about/index.shtml
# /about/sosbio.shtml
# /about/assistantsosbio.shtml
# /about/newsreleases/index.shtml
# /about/history.shtml
# /about/duties.shtml
# /about/jobs/index.shtml
# /modernization.shtml
# /about/procurement/index.shtml
# /about/publications/index.shtml
# /about/contact.shtml
# /elections/index.shtml
# https://www.votetexas.gov
# /elections/laws/voter-registration-resources.shtml
# /elections/conducting/index.shtml
# /elections/candidates/index.shtml
# /elections/voter/current.shtml
# /elections/historical/index.shtml
# /elections/fad/index.shtml
# /elections/laws/education-resources.shtml
# /elections/funds/index.shtml
# /elections/laws/resources_legal.shtml
# /elections/laws/votingsystems.shtml
# https://www.votetexas.gov/faq/index.html
# /elections/contact.shtml
# /corp/index.shtml
# /corp/sosda/index.shtml
# /corp/forms_option.shtml
# /corp/options.shtml
# https://direct.sos.state.tx.us/help/help-corp.asp?pg=fee
# /corp/copies.shtml
# /corp/registeredagents.shtml
# /ucc/index.shtml
# /corp/tradepatents.shtml
# /corp/service-of-process.shtml
# /corp/business-law.shtml
# /corp/generalfaqs.shtml
# /corp/contact.shtml
# /statdoc/index.shtml
# /statdoc/notary-public.shtml
# /authinfo.shtml
# /statdoc/npcomp.shtml
# /statdoc/faqs.shtml
# /statdoc/contact.shtml
# /texreg/index.shtml
# /texreg/index.shtml
# /tac/index.shtml
# /open/index.shtml
# /texreg/subinfo.shtml
# /texreg/transfers/index.shtml
# /texreg/liaisons.shtml
# https://webservices.sos.state.tx.us/termsandconditions/tac.html
# /texreg/resources.shtml
# /texreg/faqs.shtml
# /texreg/contact.shtml
# /border/intlprotocol/index.shtml
# /border/intlprotocol/index.shtml
# /border/intlprotocol/embassies/index.shtml
# /border/index.shtml
# /border/bmaconf.shtml
# /border/groups-reports.shtml
# /statdoc/notary-public.shtml
# /authinfo.shtml
# /border/linksofinterest.shtml
# /border/contact.shtml
# /other/index.shtml
# /forms.shtml
# https://webservices.sos.state.tx.us/legbills/index89.aspx
# /statdoc/data-brokers.shtml
# /statdoc/cso.shtml
# /statdoc/seal.shtml
# /statdoc/athlete-agents.shtml
# /statdoc/healthspas/index.shtml
# /other/faqs.shtml
# /contact.shtml
# /modernization.shtml
# /corp/sosda/index.shtml
# /corp/filingandothergeneralfaqs.shtml#CC
# /ucc/index.shtml
# /tbat/index.shtml
# https://www.votetexas.gov
# /policies.shtml
# /records.shtml
# http://www.texas.gov
# /contact.shtml
# https://www.tsl.texas.gov/trail/index.html
# http://www.texashomelandsecurity.com/
# https://comptroller.texas.gov/transparency/
# https://sao.fraud.texas.gov/ReportFraud/
# http://veterans.portal.texas.gov
# https://www.facebook.com/txsecretary
# https://www.instagram.com/texassecretary/
# https://twitter.com/TXsecofstate
# https://www.youtube.com/channel/UC7NJ9yjB4K-1MOMFzH6hAbQ/videos
# /rss/index.shtml
# https://public.govdelivery.com/accounts/TXSOS/subscriber/new?qsp=TXSOS_1

# %% [markdown]
# <b>Question 3</b> Print out the text in this webpage.

# %%
# Your code here:
print(soup.get_text())
# Out:
#
# Lubbock County Voter Registration Figures
#
#
#
# <!--
#
# function MM_jumpMenu(targ,selObj,restore){ //v3.0
#   eval(targ+".location='"+selObj.options[selObj.selectedIndex].value+"'");
#   if (restore) selObj.selectedIndex=0;
# }
# //-->
#
#
#
#
# 	@import url(/css/global-no-nav.css);
#
#
#
#
#
#
#
#
#
#
#
#   var loaderOpts = {
#     baseUrl: 'https://d2h3sz5hbsavy4.cloudfront.net/',
#     shouldLoadMinDeps: true
#   };
#   var loader = new ChatBotUiLoader.IframeLoader(loaderOpts);
#   var chatbotUiConfig = {
#           /* Example of setting session attributes on parent page
#           lex: {
#             sessionAttributes: {
#               userAgent: navigator.userAgent,
#               QNAClientFilter: ''
#             }
#           }
#           */
#         };
#   loader.load(chatbotUiConfig)
#     .catch(function (error) { console.error(error); });
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Apostille/Authentication services available by appointment on Tuesdays and Fridays starting August 5.
#
# EFFECTIVE SEPTEMBER 1, 2023, OUR LOBBY WALK-IN HOURS WILL BE 9 A.M. - 4 P.M. (CENTRAL), MONDAY - FRIDAY.
#
#
#
#
#
#
#
#         Media |
# 		Site Map |
# 		Help |
#        	Contact |
# 				Website Survey |
# 	    En Español
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search for this:
#
#
#
#
#
#
#
# 	  Menu
#
#
#
#
# 			About SOS
#
# 			  About the Office
# 						Secretary of State Biography
# 						Deputy Secretary of State Biography
# 						Press Releases
# 						History of the Office
# 						Constitutional Duties
# 						Employment Opportunities
# 						SOS Modernization Program
# 						Procurement Opportunities
# 						Publications
# 						Contact Us
#
#
#
# 			Elections & Voting
#
# 			  VoteTexas.gov - Voter Information
# 			  Voter Registration Resources
# 						Conducting Elections
# 						Candidate Information
# 						Officials and Officeholders
# 						Election Results
# 						Audit Program
# 						Training and Educational Resources
# 						Election Funds Management
# 						Forms, Resources and Legal Library
# 						Voting Systems
# 						Frequently Asked Questions (FAQS)
# 						Contact Us
#
#
#
# 				Business Services
#
# 				  SOSDirect: Business Searches & Formations
# 						Business Forms
# 						Filing Options
# 						Fee Schedule
# 						Copies and Certificates
# 						Registered Agents
# 				  Uniform Commercial Code
# 						Trademarks
# 						Service of Process
# 						Texas Business Law
# 						Frequently Asked Questions (FAQs)
# 						Contact Us
#
#
#
# 				Notary & Apostilles
#
#
# 						Notary Public
# 						Apostilles/Authentication of Documents
# 						Notary Complaints
# 						Frequently Asked Questions (FAQS)
# 						Contact Us
#
#
#
# 				Rules & Meetings
#
#
#
# 					  Texas Register
# 						Texas Administrative Code
# 						Open Meetings
# 						Subscription Services
# 						Rule Transfers and Agency Name Changes
# 						Liaison General Info
# 						Liaison Login
# 						Other Resources
# 						Frequently Asked Questions (FAQs)
# 						Contact Us
#
#
#
# 		  International Relations
#
# 					  International Affairs
# 						Foreign  Consulates in Texas
# 					  Texas Border & Mexican Affairs
# 						Border Governor's Conference
# 						Work Groups & Reports
#
# 						Notario Publico?
# 						Apostilles/Authentication of Documents
# 						Links of Interest
# 						Contact Us
#
#
#
# 			Forms & Other Services
#
# 			  Forms
# 						Legislative Bills
# 				        NEW: Data Brokers
# 						Credit Services Organizations
# 						State Seal of Texas
# 						Athlete Agents
# 						Health Spas
# 						FAQs For Other Services
# 						Contact Us
#
#
#
#
#
#
#
#
# 	const hamburger = document.querySelector('.hamburger');
# 	hamburger.addEventListener('click', function(){
# 	this.classList.toggle("close");
# 	});
#
#
#
#
#
#
# 	Lubbock County Voter Registration Figures
#
#
#             YEAR
#             Reg Voters
#             Voted
#             Voted %
#             Early Vote
#             EV %
#
#
#             1988
#             109,212
#             73,292
#             67.11%
#             10,748
#             14.66%
#
#
#             1990
#             100,347
#             51,223
#             51.05%
#             7,318
#             14.29%
#
#
#             1992
#             109,552
#             82,819
#             75.60%
#             27,881
#             33.66%
#
#
#             1994
#             109,435
#             56,664
#             51.78%
#             16,632
#             29.35%
#
#
#             1996
#             138,724
#             74,489
#             53.70%
#             23,954
#             32.16%
#
#
#             1998
#             147,535
#             49,771
#             33.74%
#             18,234
#             36.64%
#
#
#             2000
#             154,157
#             76,008
#             49.31%
#             36,247
#             47.69%
#
#
#             2002
#             152,442
#             55,581
#             36.46%
#             24,112
#             43.38%
#
#
#             2004
#             162,229
#             93,151
#             57.42%
#             58,135
#             62.41%
#
#
#             2006
#             158,399
#             53,564
#             33.82%
#             28,981
#             54.11%
#
#
#             2008
#             163,745
#             97,534
#             59.56%
#             74,810
#             45.69%
#
#
#             2010
#             150,312
#             53,675
#             35.71%
#             35,566
#             23.66%
#
#
#             2012
#             155,708
#             90,652
#             58.22%
#             65,512
#             42.07%
#
#
#             2014
#             157,054
#             47,132
#             30.01%
#             29,830
#             18.99%
#
#
#             2016
#             166,489
#             98,847
#             59.37%
#             77,029
#             46.27%
#
#
#             2018
#             170,765
#             91,972
#             54%
#             67,248
#             39%
#
#
# 			   2020
# 			   183,320
# 			   120,204
# 			   65.57%
# 			   106,281
# 			   57.98%
#
#
# 			  2022
# 			  187,728
# 			  83,768
# 			  44.62%
# 			  60,130
# 			  32.03%
#
#
#
#
#
#
#
#
#          NEW: SOS Modernization Program
#         SOSDirect -Business Filings
#         Business Copies and Certificates
#         Uniform Commercial Code
#         Texas Businesses Against Trafficking
#
#
#
#
#
#
# 	  VoteTexas.gov - Voter Information
# 	  Website Policies
# 	  Open Records
# 	  Texas.gov
# 	  Contacts
#
#
#
#
#
#
#         Texas State Library & Archives
#         Texas Homeland Security
# 	    Where the Money Goes
#         Fraud Reporting
#         Texas Veterans Portal
